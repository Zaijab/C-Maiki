# 2016-05-31 08:30:00  22.465  20.746
# 2016-05-31 09:00:00  23.497  21.318
# 2016-05-31 09:30:00  23.689   19.27
# 2016-05-31 10:00:00  23.689  16.701
# 2016-05-31 10:30:00  23.304  17.368
# 2016-05-31 11:00:00  23.016  17.748
# 2016-05-31 11:30:00  22.657  18.414
# 2016-05-31 12:00:00   23.16  18.747
# 2016-05-31 12:30:00  24.339  21.987
# 2016-05-31 13:00:00  24.243    22.8
# 2016-05-31 13:30:00  26.793  24.339
# 2016-05-31 14:00:00  27.112  24.702
# 2016-05-31 14:30:00  27.259  25.525
# 2016-05-31 15:00:00  27.284  25.065
# 2016-05-31 15:30:00  27.604  26.426
# 2016-05-31 16:00:00  27.554  22.705
# 2016-05-31 16:30:00  27.456  22.896
# 2016-05-31 17:00:00  27.505  22.561
# 2016-05-31 17:30:00  27.751  24.919
# 2016-05-31 18:00:00  27.235  24.484
# 2016-05-31 18:30:00   26.28  23.448
# 2016-05-31 19:00:00  27.382  24.968
# 2016-05-31 19:30:00  26.256  22.369
# 2016-05-31 20:00:00  24.968  21.676
# 2016-05-31 20:30:00   23.16  21.079
# 2016-05-31 21:00:00  24.195   19.77
# 2016-05-31 21:30:00  24.532  23.112
# 2016-05-31 22:00:00  24.726  21.724
# 2016-05-31 22:30:00  24.195  22.633
# 2016-05-31 23:00:00  23.521  21.175
# 2016-05-31 23:30:00  26.916  21.533

# %%
ten_meter_by_days = [days['10m'].values.tolist() for days in data_by_days]

# %%
#Compute Distances
c1_distance_matrix = analysis.distance_matrix(data_by_days[0].T.values)
analysis.plotter(c1_distance_matrix,data.columns.tolist())

# %%
analysis.plotter(analysis.distance_matrix(data_by_days[0].T.values),data.columns.tolist(),"August")
analysis.plotter(analysis.distance_matrix(data_by_days[31].T.values),data.columns.tolist(),"September")
analysis.plotter(analysis.distance_matrix(data_by_days[61].T.values),data.columns.tolist(),"October")
analysis.plotter(analysis.distance_matrix(data_by_days[92].T.values),data.columns.tolist(),"November")
analysis.plotter(analysis.distance_matrix(data_by_days[122].T.values),data.columns.tolist(),"December")
analysis.plotter(analysis.distance_matrix(data_by_days[153].T.values),data.columns.tolist(),"January")
analysis.plotter(analysis.distance_matrix(data_by_days[184].T.values),data.columns.tolist(),"February")
analysis.plotter(analysis.distance_matrix(data_by_days[213].T.values),data.columns.tolist(),"March")
analysis.plotter(analysis.distance_matrix(data_by_days[244].T.values),data.columns.tolist(),"April")
analysis.plotter(analysis.distance_matrix(data_by_days[274].T.values),data.columns.tolist(),"May")
analysis.plotter(analysis.distance_matrix(data_by_days[305].T.values),data.columns.tolist(),"June")
analysis.plotter(analysis.distance_matrix(data_by_days[335].T.values),data.columns.tolist(),"July")

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.imshow(ten_meter_distances, interpolation='nearest')
fig.colorbar(cax)
ax.set_title("Day vs Day Distance Matrix at 10m")
ax.xaxis.set_major_locator(ticker.FixedLocator([0,31,61,92,122,153,184,213,244,274,305,335]))
ax.yaxis.set_major_locator(ticker.FixedLocator([0,31,61,92,122,153,184,213,244,274,305,335]))
ax.set_yticklabels(["August","September","October","November","December","January","February","March","April","May","June","July"])
ax.set_xticklabels(["August","September","October","November","December","January","February","March","April","May","June","July"])
plt.xticks(rotation='vertical')
plt.show()

# %%
#ten_meter_distances = analysis.distance_matrix(ten_meter_by_days)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.imshow(ten_meter_distances, interpolation='nearest')
fig.colorbar(cax)
ax.set_title("Day vs Day Distance Matrix at 10m")
ax.xaxis.set_major_locator(ticker.FixedLocator([0,200,300]))
ax.yaxis.set_major_locator(ticker.FixedLocator([0,200,300]))
ax.set_yticklabels(["August 5, 2015","February 21, 2016","May 31, 2016"])
ax.set_xticklabels(["August 5, 2015","February 21, 2016","May 31, 2016"])
plt.xticks(rotation='vertical')
plt.show()

# %%
fig = plt.figure()
ax = plt.subplot(111)
ax.plot(ten_meter_distances[0])
ax.plot(ten_meter_distances[200])
ax.plot(ten_meter_distances[300])
ax.legend(["August 5, 2015","February 21, 2016","May 31, 2016"],bbox_to_anchor=(1,1))

#for i in range(len(ten_meter_distances)):
#    plt.plot(ten_meter_distances[i])

# %%
ten_meter_distances_laplacian = csgraph.laplacian(ten_meter_distances)
w,v = LA.eig(ten_meter_distances_laplacian)
print(v)

plt.hist(ten_meter_distances.flatten())
# Out:
# [[ 1.31147353e-02 -5.41538037e-02  1.67831872e-04 ... -3.48259985e-04
#   -8.17654094e-04 -1.48532256e-04]
#  [ 9.18653486e-03 -5.41535864e-02  1.07070977e-03 ...  4.47704677e-03
#   -5.89542307e-03 -6.73918057e-03]
#  [ 1.21317733e-02 -5.41529195e-02  3.80374945e-04 ...  4.95664847e-03
#   -5.41655717e-04 -3.98068117e-03]
#  ...
#  [ 1.16725895e-01 -5.41539250e-02 -3.21921161e-02 ...  4.77967063e-05
#    5.02818745e-05 -1.86513254e-05]
#  [ 1.61362184e-01 -5.41538655e-02 -6.08594082e-02 ...  5.45800917e-05
#    2.53216767e-05 -9.97385529e-06]
#  [ 1.67918366e-01 -5.41251783e-02 -6.69325869e-02 ...  2.97920021e-05
#    2.14044187e-05 -8.72494500e-06]]
# (array([16951., 26826., 21530., 18000., 12510.,  9532.,  5840.,  3254.,
#          1558.,   280.]),
#  array([ 0.        ,  1.18100851,  2.36201702,  3.54302552,  4.72403403,
#          5.90504254,  7.08605105,  8.26705955,  9.44806806, 10.62907657,
#         11.81008508]),
#  <a list of 10 Patch objects>)

# %%
from clustergrammer_widget import Network
net = Network()

# load matrix file
net.load_df(data)

# calculate clustering
net.make_clust(dist_type='cos',views=['N_row_sum', 'N_row_var'])

net.widget()

#makani.manoa.hawaii.edu:1000
# Out:
# make_clust method will be deprecated in next version, please use cluster method.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-77-b3469ab02ef7> in <module>
#       6
#       7 # calculate clustering
# ----> 8 net.make_clust(dist_type='cos',views=['N_row_sum', 'N_row_var'])
#       9
#      10 net.widget()
#
# ~/.local/lib64/python3.6/site-packages/clustergrammer_widget/clustergrammer/__init__.py in make_clust(self, dist_type, run_clustering, dendro, views, linkage_type, sim_mat, filter_sim, calc_cat_pval, run_enrichr, enrichrgram)
#     118                                    calc_cat_pval=calc_cat_pval,
#     119                                    run_enrichr=run_enrichr,
# --> 120                                    enrichrgram=enrichrgram)
#     121
#     122   def produce_view(self, requested_view=None):
#
# ~/.local/lib64/python3.6/site-packages/clustergrammer_widget/clustergrammer/make_clust_fun.py in make_clust(net, dist_type, run_clustering, dendro, requested_views, linkage_type, sim_mat, filter_sim, calc_cat_pval, sim_mat_views, run_enrichr, enrichrgram)
#      43   if 'N_row_sum' in requested_views:
#      44     all_views = make_views.N_rows(net, send_df, all_views,
# ---> 45                                   dist_type=dist_type, rank_type='sum')
#      46
#      47   if 'N_row_var' in requested_views:
#
# ~/.local/lib64/python3.6/site-packages/clustergrammer_widget/clustergrammer/make_views.py in N_rows(net, df, all_views, dist_type, rank_type)
#      26         keep_rows = rows_sorted[0:inst_keep]
#      27
# ---> 28         tmp_df['mat'] = tmp_df['mat'].ix[keep_rows]
#      29         if 'mat_up' in tmp_df:
#      30           tmp_df['mat_up'] = tmp_df['mat_up'].ix[keep_rows]
#
# ~/.local/lib64/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     124
#     125             key = com.apply_if_callable(key, self.obj)
# --> 126             return self._getitem_axis(key, axis=axis)
#     127
#     128     def _get_label(self, label, axis=None):
#
# ~/.local/lib64/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1086                 raise ValueError('Cannot index with multidimensional key')
#    1087
# -> 1088             return self._getitem_iterable(key, axis=axis)
#    1089         else:
#    1090
#
# ~/.local/lib64/python3.6/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1203             # A collection of keys
#    1204             keyarr, indexer = self._get_listlike_indexer(key, axis,
# -> 1205                                                          raise_missing=False)
#    1206             return self.obj._reindex_with_indexers({axis: [keyarr, indexer]},
#    1207                                                    copy=True, allow_dups=True)
#
# ~/.local/lib64/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1145             self._validate_read_indexer(key, indexer, axis,
#    1146                                         raise_missing=raise_missing)
# -> 1147             return ax[indexer], indexer
#    1148
#    1149         if ax.is_unique:
#
# ~/.local/lib64/python3.6/site-packages/pandas/core/indexes/datetimes.py in __getitem__(self, key)
#    1168
#    1169     def __getitem__(self, key):
# -> 1170         result = self._data.__getitem__(key)
#    1171         if is_scalar(result):
#    1172             return result
#
# ~/.local/lib64/python3.6/site-packages/pandas/core/arrays/datetimelike.py in __getitem__(self, key)
#     449                 freq = self.freq
#     450
# --> 451         result = getitem(key)
#     452         if result.ndim > 1:
#     453             # To support MPL which performs slicing with 2 dim
#
# IndexError: index 1467253800000000000 is out of bounds for axis 0 with size 16321
